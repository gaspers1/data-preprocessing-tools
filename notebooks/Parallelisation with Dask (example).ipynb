# %%
import numpy as np
import graphviz
import dask.array as da

# %%
x = np.arange(10000000).reshape(10000, 1000)

# %%
x
# Out:
# array([[      0,       1,       2, ...,     997,     998,     999],
#        [   1000,    1001,    1002, ...,    1997,    1998,    1999],
#        [   2000,    2001,    2002, ...,    2997,    2998,    2999],
#        ...,
#        [9997000, 9997001, 9997002, ..., 9997997, 9997998, 9997999],
#        [9998000, 9998001, 9998002, ..., 9998997, 9998998, 9998999],
#        [9999000, 9999001, 9999002, ..., 9999997, 9999998, 9999999]])

# %%
a = da.from_array(x, chunks=1000)

# %%
a.visualize()

# %%
a.sum().visualize()

# %%
a.sum().compute()
# Out:
# -2014260032
